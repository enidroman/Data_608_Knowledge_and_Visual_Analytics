# %% [markdown]
# <a href="https://colab.research.google.com/github/enidroman/Data_608_Knowledge_and_Visual_Analytics/blob/main/Enid_Roman_Data_608_Story_1_Infrastructure_Investment_%26_Jobs_Act_Funding_Allocation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the pandas package.
import pandas as pd
import numpy as np

# %% [markdown]
# ## **THE DATA SET**

# %% [markdown]
#  Population dataset came from https://worldpopulationreview.com/states
#
#  Politcal Party came from https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/42MVDX
#
#  Infrastructure Investment & Jobs Act Funding Allocation excel was provided by the professor.
#
#  I did some of cleaning in excel for the 2 excels I found on the website.

# %%
# Load the dataset after is saved in github.
df1 = pd.read_csv('https://raw.githubusercontent.com/enidroman/Data_608_Knowledge_and_Visual_Analytics/main/IIJA%20FUNDING%20AS%20OF%20MARCH%202023(1)%20(1).csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/enidroman/Data_608_Knowledge_and_Visual_Analytics/main/state-population.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/enidroman/Data_608_Knowledge_and_Visual_Analytics/ba6668f687ce482e2ac1cd0ba897f036bebbaaec/2020-president.csv')

# %% [markdown]
# ### **Infrastructure Investment & Jobs Act Funding Allocation by State**

# %%
df1.head()
# Out:
#   State, Teritory or Tribal Nation  Total (Billions)
# 0                          ALABAMA            3.0000
# 1                           ALASKA            3.7000
# 2                   AMERICAN SAMOA            0.0686
# 3                          ARIZONA            3.5000
# 4                         ARKANSAS            2.8000

# %%
df1 = df1.rename(columns={'State, Teritory or Tribal Nation': 'State'})
df1.head()
# Out:
#             State  Total (Billions)
# 0         ALABAMA            3.0000
# 1          ALASKA            3.7000
# 2  AMERICAN SAMOA            0.0686
# 3         ARIZONA            3.5000
# 4        ARKANSAS            2.8000

# %% [markdown]
# ### **Population by State**

# %%
df2.head()
# Out:
#             State   Pop 2023
# 0         ALABAMA  5098746.0
# 1          ALASKA   732984.0
# 2  AMERICAN SAMOA        NaN
# 3         ARIZONA  7453517.0
# 4        ARKANSAS  3063152.0

# %% [markdown]
# ### **Politcal Party by State**

# %%
df3.head()
# Out:
#             State   Democrat  Republican  Libertarian    Other
# 0         ALABAMA   849624.0   1441170.0      25176.0   7312.0
# 1          ALASKA   153778.0    189951.0       8897.0   6904.0
# 2  AMERICAN SAMOA        NaN         NaN          NaN      NaN
# 3         ARIZONA  1672143.0   1661686.0      51465.0   2032.0
# 4        ARKANSAS   423932.0    760647.0      13133.0  21357.0

# %% [markdown]
# ### **Infrastructure Investment & Jobs Act Funding Allocation and Population by State**

# %%
df_merged_1 = df1.merge(df2, how='outer')
df_merged_1.head()
# Out:
#             State  Total (Billions)   Pop 2023
# 0         ALABAMA            3.0000  5098746.0
# 1          ALASKA            3.7000   732984.0
# 2  AMERICAN SAMOA            0.0686        NaN
# 3         ARIZONA            3.5000  7453517.0
# 4        ARKANSAS            2.8000  3063152.0

# %% [markdown]
# ### **Infrastructure Investment & Jobs Act Funding Allocation, Population, Political Party by State**

# %%
df_merged_all = df_merged_1.merge(df3, how='outer')
df_merged_all.head()
# Out:
#             State  Total (Billions)   Pop 2023   Democrat  Republican  \
# 0         ALABAMA            3.0000  5098746.0   849624.0   1441170.0
# 1          ALASKA            3.7000   732984.0   153778.0    189951.0
# 2  AMERICAN SAMOA            0.0686        NaN        NaN         NaN
# 3         ARIZONA            3.5000  7453517.0  1672143.0   1661686.0
# 4        ARKANSAS            2.8000  3063152.0   423932.0    760647.0
#
#    Libertarian    Other
# 0      25176.0   7312.0
# 1       8897.0   6904.0
# 2          NaN      NaN
# 3      51465.0   2032.0
# 4      13133.0  21357.0

# %%
df_merged_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 57
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             58 non-null     object
#  1   Total (Billions)  57 non-null     float64
#  2   Pop 2023          52 non-null     float64
#  3   Democrat          51 non-null     float64
#  4   Republican        51 non-null     float64
#  5   Libertarian       49 non-null     float64
#  6   Other             48 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.6+ KB

# %%
#df_left = df_merged_all.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')])])
#df_left

# %%
from google.colab import data_table
from vega_datasets import data

data_table.enable_dataframe_formatter()

df_merged_all
# Out:
#                        State  Total (Billions)    Pop 2023    Democrat  \
# 0                    ALABAMA            3.0000   5098746.0    849624.0
# 1                     ALASKA            3.7000    732984.0    153778.0
# 2             AMERICAN SAMOA            0.0686         NaN         NaN
# 3                    ARIZONA            3.5000   7453517.0   1672143.0
# 4                   ARKANSAS            2.8000   3063152.0    423932.0
# 5                 CALIFORNIA           18.4000  38915693.0  11110250.0
# 6                   COLORADO            3.2000   5868555.0   1804352.0
# 7                CONNECTICUT            2.5000   3629055.0   1080831.0
# 8                   DELEWARE            0.7920         NaN         NaN
# 9       DISTRICT OF COLUMBIA            1.1000    674815.0    317323.0
# 10                   FLORIDA            8.2000  22661577.0   5297045.0
# 11                   GEORGIA            5.0000  11037723.0   2473633.0
# 12                      GUAM            0.1426         NaN         NaN
# 13                    HAWAII            1.0000   1433238.0    366130.0
# 14                     IDAHO            1.2000   1973752.0    287021.0
# 15                  ILLINOIS            8.4000  12477595.0   3471915.0
# 16                   INDIANA            3.4000   6852542.0   1242416.0
# 17                      IOWA            2.4000   3203345.0    897672.0
# 18                    KANSAS            1.5000   2936378.0    771406.0
# 19                  KENTUCKY            3.9000   4518031.0   1326646.0
# 20                 LOUISIANA            4.3000   4553384.0    856034.0
# 21                     MAINE            1.1000   1393442.0    435072.0
# 22                  MARYLAND            2.7000   6154710.0    976414.0
# 23             MASSACHUSETTS            3.6000   6974258.0   2382202.0
# 24                  MICHIGAN            5.2000  10030722.0   2804040.0
# 25                 MINNESOTA            2.7000   5722897.0   1484065.0
# 26               MISSISSIPPI            2.3000   2930528.0    539398.0
# 27                  MISSOURI            3.8000   6186091.0   1718736.0
# 28                   MONTANA            3.3000   1139507.0    244786.0
# 29                  NEBRASKA            1.3000   1972292.0    556846.0
# 30                    NEVADA            1.7000   3209142.0    703486.0
# 31             NEW HAMPSHIRE            0.7518   1402957.0    424921.0
# 32                NEW JERSEY            5.1000   9255437.0   2608335.0
# 33                NEW MEXICO            2.6000   2110011.0    501614.0
# 34                  NEW YORK           10.1000  19496810.0   5230985.0
# 35            NORTH CAROLINA            4.5000  10832061.0   2684292.0
# 36              NORTH DAKOTA            1.8000    780588.0    114902.0
# 37  NORTHERN MARIANA ISLANDS            0.0833         NaN         NaN
# 38                      OHIO            6.6000  11747774.0   2679165.0
# 39                  OKLAHOMA            2.9000   4048375.0    503890.0
# 40                    OREGON            2.3000   4223973.0   1340383.0
# 41              PENNSYLVANIA            8.1000  12931957.0   3458229.0
# 42               PUERTO RICO            0.9937   3180885.0         NaN
# 43              RHODE ISLAND            1.1000   1090483.0    307486.0
# 44            SOUTH CAROLINA            2.3000   5372002.0   1091541.0
# 45              SOUTH DAKOTA            1.3000    923484.0    150471.0
# 46                 TENNESSEE            3.7000   7134327.0   1143711.0
# 47                     TEXAS           14.2000  30500280.0   5259126.0
# 48        TRIBAL COMMUNITIES            3.0000         NaN         NaN
# 49         US VIRGIN ISLANDS            0.1483         NaN         NaN
# 50                      UTAH            1.8000   3422487.0    560282.0
# 51                   VERMONT            0.8521    647156.0    242820.0
# 52                  VIRGINIA            4.5000   8709873.0   2413568.0
# 53                WASHINGTON            4.0000   7830827.0   2369612.0
# 54             WEST VIRGINIA            2.0000   1764786.0    235984.0
# 55                 WISCONSIN            2.8000   5904977.0   1630866.0
# 56                   WYOMING            2.3000    583279.0     73491.0
# 57                  DELAWARE               NaN   1031985.0    296268.0
#
#     Republican  Libertarian     Other
# 0    1441170.0      25176.0    7312.0
# 1     189951.0       8897.0    6904.0
# 2          NaN          NaN       NaN
# 3    1661686.0      51465.0    2032.0
# 4     760647.0      13133.0   21357.0
# 5    6006429.0     187895.0  196307.0
# 6    1364607.0      52460.0   58561.0
# 7     714717.0      20230.0    8079.0
# 8          NaN          NaN       NaN
# 9      18586.0       2036.0    6411.0
# 10   5668731.0      70324.0   31356.0
# 11   2461854.0      62229.0    2244.0
# 12         NaN          NaN       NaN
# 13    196864.0       5539.0   11251.0
# 14    554119.0      16404.0   10470.0
# 15   2446891.0      66544.0   48393.0
# 16   1729519.0      59232.0    1951.0
# 17    759061.0      19637.0   23760.0
# 18    570323.0      30574.0       NaN
# 19    772474.0      26234.0   11414.0
# 20     21645.0    1255776.0   14607.0
# 21     14152.0     360737.0   18344.0
# 22   1985023.0      33488.0   26306.0
# 23   1167202.0      47013.0   61588.0
# 24   2649852.0      60381.0   25029.0
# 25   1717077.0      34976.0   41053.0
# 26    756764.0       8026.0    9571.0
# 27   1253014.0      41205.0   13007.0
# 28    343602.0      15252.0      34.0
# 29    374583.0      20283.0    4671.0
# 30    669890.0      14783.0   17217.0
# 31    365654.0      13235.0    2372.0
# 32   1883274.0      31677.0   30493.0
# 33    401894.0      12585.0    3446.0
# 34   3244798.0      60234.0  125718.0
# 35   2758773.0      48678.0   33505.0
# 36    235595.0       9393.0    1929.0
# 37         NaN          NaN       NaN
# 38   3154834.0      67569.0   20634.0
# 39   1020280.0      24731.0   11798.0
# 40    958448.0      41582.0   33908.0
# 41   3377674.0      79380.0       NaN
# 42         NaN          NaN       NaN
# 43    199922.0       5053.0    4529.0
# 44   1385103.0      27916.0    9536.0
# 45    261043.0      11095.0       NaN
# 46   1852475.0          NaN   57665.0
# 47   5890347.0     126243.0   39340.0
# 48         NaN          NaN       NaN
# 49         NaN          NaN       NaN
# 50    865140.0      38447.0   24420.0
# 51    112704.0       3608.0   11836.0
# 52   1962430.0      64761.0   19765.0
# 53   1584651.0      80500.0   52868.0
# 54    545382.0      10687.0    2599.0
# 55   1610184.0          NaN   56991.0
# 56    193559.0       5768.0    5685.0
# 57    200603.0       5000.0    2475.0

# %% [markdown]
# ### **Population by State**

# %%
import matplotlib.pyplot as plt

sort_df = df_merged_all.sort_values(by='Pop 2023', ascending=False)

# Create the bar chart
plt.figure(figsize=(17, 14))
bars = plt.bar('State', 'Pop 2023', data=sort_df, color='blue')
plt.xlabel('State')
plt.ylabel('Population')
plt.title('Population by State')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability


# Add annotations above the bars
for bar in bars:
    height = bar.get_height()
    plt.annotate(f'{height:.2f}',  # Format the annotation text as needed
                 xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 10),  # Adjust the vertical position
                 textcoords="offset points",
                 ha='center',
                 fontsize=10,
                 rotation=90)


# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Infrastructure Investment & Jobs Act Funding Allocation by State**

# %%
import matplotlib.pyplot as plt

sort_df = df_merged_all.sort_values(by='Total (Billions)', ascending=False)

# Create the bar chart
plt.figure(figsize=(17, 14))
bars = plt.bar('State', 'Total (Billions)', data=sort_df, color='blue')
plt.xlabel('State')
plt.ylabel('Total (Billions)')
plt.title('Allocation of the Infrastructure Investment and Jobs Act funding by State and Territory')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability


# Add annotations above the bars
for bar in bars:
    height = bar.get_height()
    plt.annotate(f'{height:.2f}',  # Format the annotation text as needed
                 xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 10),  # Adjust the vertical position
                 textcoords="offset points",
                 ha='center',
                 fontsize=10,
                 rotation=90)


# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# ###**Political Party by State**

# %%
# Extract the relevant columns for plotting
states = df_merged_all['State']
party = ['Democrat', 'Republican', 'Libertarian', 'Other']

# Define the width of each bar and the x-axis positions
bar_width = 0.20
index = np.arange(len(states))

# Create a color map for parties
party_colors = {
    'Democrat': 'blue',
    'Republican': 'red',
    'Libertarian': 'green',
    'Other': 'purple'
}

# Create the side-by-side grouped bar chart
plt.figure(figsize=(17, 10))

for i, party in enumerate(party):
    plt.bar(index + i * bar_width, df_merged_all[party], bar_width, label=party, color=party_colors[party])

plt.xlabel('State')
plt.ylabel('Votes')
plt.title('Votes by State')
plt.xticks(index + bar_width * (len(party) - 1) / 5, states)
plt.xticks(rotation=90)


plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #**Question 1**

# %% [markdown]
# # **Is the allocation equitable based on the population of each of the States and Territories, or is bias apparent?**

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter(x=df_merged_all['State'], y=df_merged_all['Total (Billions)'], name="Total (Billions)"),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=df_merged_all['State'], y=df_merged_all['Pop 2023'], name="Population"),
    secondary_y=True,
)

# Add figure title
fig.update_layout(
    title_text="Allocation of the Infrastructure Investment and Jobs Act funding and Population by State and Territory"
)

# Set x-axis title
fig.update_xaxes(title_text="State")

# Set y-axes titles
fig.update_yaxes(title_text="Total (Billions)", secondary_y=False)
fig.update_yaxes(title_text="Population", secondary_y=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6f7898e6-a587-42e7-bc7f-f55b79faa7e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f7898e6-a587-42e7-bc7f-f55b79faa7e3")) {                    Plotly.newPlot(                        "6f7898e6-a587-42e7-bc7f-f55b79faa7e3",                        [{"name":"Total (Billions)","x":["ALABAMA","ALASKA","AMERICAN SAMOA","ARIZONA","ARKANSAS","CALIFORNIA","COLORADO","CONNECTICUT","DELEWARE","DISTRICT OF COLUMBIA","FLORIDA","GEORGIA","GUAM","HAWAII","IDAHO","ILLINOIS","INDIANA","IOWA","KANSAS","KENTUCKY","LOUISIANA","MAINE","MARYLAND","MASSACHUSETTS","MICHIGAN","MINNESOTA","MISSISSIPPI","MISSOURI","MONTANA","NEBRASKA","NEVADA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEW YORK","NORTH CAROLINA","NORTH DAKOTA","NORTHERN MARIANA ISLANDS","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","PUERTO RICO","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","TRIBAL COMMUNITIES","US VIRGIN ISLANDS","UTAH","VERMONT","VIRGINIA","WASHINGTON","WEST VIRGINIA","WISCONSIN","WYOMING","DELAWARE"],"y":[3.0,3.7,0.0686,3.5,2.8,18.4,3.2,2.5,0.792,1.1,8.2,5.0,0.1426,1.0,1.2,8.4,3.4,2.4,1.5,3.9,4.3,1.1,2.7,3.6,5.2,2.7,2.3,3.8,3.3,1.3,1.7,0.7518,5.1,2.6,10.1,4.5,1.8,0.0833,6.6,2.9,2.3,8.1,0.9937,1.1,2.3,1.3,3.7,14.2,3.0,0.1483,1.8,0.8521,4.5,4.0,2.0,2.8,2.3,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Population","x":["ALABAMA","ALASKA","AMERICAN SAMOA","ARIZONA","ARKANSAS","CALIFORNIA","COLORADO","CONNECTICUT","DELEWARE","DISTRICT OF COLUMBIA","FLORIDA","GEORGIA","GUAM","HAWAII","IDAHO","ILLINOIS","INDIANA","IOWA","KANSAS","KENTUCKY","LOUISIANA","MAINE","MARYLAND","MASSACHUSETTS","MICHIGAN","MINNESOTA","MISSISSIPPI","MISSOURI","MONTANA","NEBRASKA","NEVADA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEW YORK","NORTH CAROLINA","NORTH DAKOTA","NORTHERN MARIANA ISLANDS","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","PUERTO RICO","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","TRIBAL COMMUNITIES","US VIRGIN ISLANDS","UTAH","VERMONT","VIRGINIA","WASHINGTON","WEST VIRGINIA","WISCONSIN","WYOMING","DELAWARE"],"y":[5098746.0,732984.0,null,7453517.0,3063152.0,38915693.0,5868555.0,3629055.0,null,674815.0,22661577.0,11037723.0,null,1433238.0,1973752.0,12477595.0,6852542.0,3203345.0,2936378.0,4518031.0,4553384.0,1393442.0,6154710.0,6974258.0,10030722.0,5722897.0,2930528.0,6186091.0,1139507.0,1972292.0,3209142.0,1402957.0,9255437.0,2110011.0,19496810.0,10832061.0,780588.0,null,11747774.0,4048375.0,4223973.0,12931957.0,3180885.0,1090483.0,5372002.0,923484.0,7134327.0,30500280.0,null,null,3422487.0,647156.0,8709873.0,7830827.0,1764786.0,5904977.0,583279.0,1031985.0],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7 ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=2, cols=1,
                    specs=[[{"secondary_y": True}], [{"secondary_y": True}]],
                    shared_xaxes=True  # Share the x-axis
                           )

# Top left
fig.add_trace(
    go.Scatter(x=df_merged_all['State'], y=df_merged_all['Total (Billions)'], name="Total Billions"),
    row=1, col=1,secondary_y=False)

fig.add_trace(
    go.Scatter(x=df_merged_all['State'], y=df_merged_all['Pop 2023'], name="Population"),
    row=2, col=1, secondary_y=False
)

# Customize the layout and add a title
fig.update_layout(title_text='Allocation vs. Population by State',
                  xaxis_tickangle=-45,
                                    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="930a5836-641a-4f4d-bffe-5b85c674ec4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("930a5836-641a-4f4d-bffe-5b85c674ec4c")) {                    Plotly.newPlot(                        "930a5836-641a-4f4d-bffe-5b85c674ec4c",                        [{"name":"Total Billions","x":["ALABAMA","ALASKA","AMERICAN SAMOA","ARIZONA","ARKANSAS","CALIFORNIA","COLORADO","CONNECTICUT","DELEWARE","DISTRICT OF COLUMBIA","FLORIDA","GEORGIA","GUAM","HAWAII","IDAHO","ILLINOIS","INDIANA","IOWA","KANSAS","KENTUCKY","LOUISIANA","MAINE","MARYLAND","MASSACHUSETTS","MICHIGAN","MINNESOTA","MISSISSIPPI","MISSOURI","MONTANA","NEBRASKA","NEVADA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEW YORK","NORTH CAROLINA","NORTH DAKOTA","NORTHERN MARIANA ISLANDS","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","PUERTO RICO","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","TRIBAL COMMUNITIES","US VIRGIN ISLANDS","UTAH","VERMONT","VIRGINIA","WASHINGTON","WEST VIRGINIA","WISCONSIN","WYOMING","DELAWARE"],"y":[3.0,3.7,0.0686,3.5,2.8,18.4,3.2,2.5,0.792,1.1,8.2,5.0,0.1426,1.0,1.2,8.4,3.4,2.4,1.5,3.9,4.3,1.1,2.7,3.6,5.2,2.7,2.3,3.8,3.3,1.3,1.7,0.7518,5.1,2.6,10.1,4.5,1.8,0.0833,6.6,2.9,2.3,8.1,0.9937,1.1,2.3,1.3,3.7,14.2,3.0,0.1483,1.8,0.8521,4.5,4.0,2.0,2.8,2.3,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Population","x":["ALABAMA","ALASKA","AMERICAN SAMOA","ARIZONA","ARKANSAS","CALIFORNIA","COLORADO","CONNECTICUT","DELEWARE","DISTRICT OF COLUMBIA","FLORIDA","GEORGIA","GUAM","HAWAII","IDAHO","ILLINOIS","INDIANA","IOWA","KANSAS","KENTUCKY","LOUISIANA","MAINE","MARYLAND","MASSACHUSETTS","MICHIGAN","MINNESOTA","MISSISSIPPI","MISSOURI","MONTANA","NEBRASKA","NEVADA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEW YORK","NORTH CAROLINA","NORTH DAKOTA","NORTHERN MARIANA ISLANDS","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","PUERTO RICO","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","TRIBAL COMMUNITIES","US VIRGIN ISLANDS","UTAH","VERMONT","VIRGINIA","WASHINGTON","WEST VIRGINIA","WISCONSIN","WYOMING","DELAWARE"],"y":[5098746.0,732984.0,null,7453517.0,3063152.0,38915693.0,5868555.0,3629055.0,null,674815.0,22661577.0,11037723.0,null,1433238.0,1973752.0,12477595.0,6852542.0,3203345.0,2936378.0,4518031.0,4553384.0,1393442.0,6154710.0,6974258.0,10030722.0,5722897.0,2930528.0,6186091.0,1139507.0,1972292.0,3209142.0,1402957.0,9255437.0,2110011.0,19496810.0,10832061.0,780588.0,null,11747774.0,4048375.0,4223973.0,12931957.0,3180885.0,1090483.0,5372002.0,923484.0,7134327.0,30500280.0,null,null,3422487.0,647156.0,8709873.0,7830827.0,1764786.0,5904977.0,583279.0,1031985.0],"type":"scatter","xaxis":"x2","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#72 ...

# %% [markdown]
# As per the graph above, I don't see any bias in the allocation of funds that were distributed to each state. I believe the allocation of funds were equitable based on the population of each of the States and Territories.

# %% [markdown]
# #**Question 2**

# %% [markdown]
# # **Does the allocation favor the political interests of the Biden administration?****

# %% [markdown]
# **Please note on the graphs below that shows 2 different types of graphs in one for some reason I set the states to a 90 degree angle to see them better for for some reason it did not work for these graphs.**

# %%
# Create a figure with two subplots
fig, ax1 = plt.subplots(figsize=(10, 6))

# Create the bar chart on the left axis
ax1.bar(df_merged_all['State'], df_merged_all['Democrat'], color='b', alpha=0.7, label='Bar Chart')
ax1.set_xlabel('State')
ax1.set_ylabel('Democrat', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create a second y-axis on the right for the line chart
ax2 = ax1.twinx()
ax2.plot(df_merged_all['State'], df_merged_all['Total (Billions)'], color='y', marker='o', linestyle='-', label='Line Chart')
ax2.set_ylabel('Total (Billions)', color='y')
ax2.tick_params(axis='y', labelcolor='y')

# Rotate the x-axis labels
plt.xticks(rotation=90)  # Adjust the rotation angle as needed

# Add a legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax1.legend(lines, labels, loc='upper left')

# Add a title
plt.title('Allocation of the Infrastructure Investment and Jobs Act funding by State and Territory -  Democrat Party ')

plt.tight_layout()
plt.show()

# %%
# Create a figure with two subplots
fig, ax1 = plt.subplots(figsize=(10, 6))

# Create the bar chart on the left axis
ax1.bar(df_merged_all['State'], df_merged_all['Republican'], color='r', alpha=0.7, label='Republican')
ax1.set_xlabel('State')
ax1.set_ylabel('Republican', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# Create a second y-axis on the right for the line chart
ax2 = ax1.twinx()
ax2.plot(df_merged_all['State'], df_merged_all['Total (Billions)'], color='y', marker='o', linestyle='-', label='Funding')
ax2.set_ylabel('Total (Billions)', color='y')
ax2.tick_params(axis='y', labelcolor='y')

# Rotate the x-axis labels
plt.xticks(rotation=90)  # Adjust the rotation angle as needed

# Add a legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax1.legend(lines, labels, loc='upper left')

# Add a title
plt.title('Allocation of the Infrastructure Investment and Jobs Act funding by State and Territory -  Republican Party ')

plt.tight_layout()
plt.show()

# %%
# Create a figure with two subplots
fig, ax1 = plt.subplots(figsize=(10, 6))

# Create the bar chart on the left axis
ax1.bar(df_merged_all['State'], df_merged_all['Libertarian'], color='g', alpha=0.7, label='Libertarian')
ax1.set_xlabel('State')
ax1.set_ylabel('Libertarian', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Create a second y-axis on the right for the line chart
ax2 = ax1.twinx()
ax2.plot(df_merged_all['State'], df_merged_all['Total (Billions)'], color='y', marker='o', linestyle='-', label='Funding')
ax2.set_ylabel('Total (Billions)', color='y')
ax2.tick_params(axis='y', labelcolor='y')

# Rotate the x-axis labels
plt.xticks(rotation=90)  # Adjust the rotation angle as needed

# Add a legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax1.legend(lines, labels, loc='upper left')

# Add a title
plt.title('Allocation of the Infrastructure Investment and Jobs Act funding by State and Territory -  Libertarian Party ')

plt.tight_layout()
plt.show()

# %%
# Create a figure with two subplots
fig, ax1 = plt.subplots(figsize=(10, 6))

# Create the bar chart on the left axis
ax1.bar(df_merged_all['State'], df_merged_all['Other'], color='purple', alpha=0.7, label='Other')
ax1.set_xlabel('State')
ax1.set_ylabel('Other', color='purple')
ax1.tick_params(axis='y', labelcolor='purple')

# Create a second y-axis on the right for the line chart
ax2 = ax1.twinx()
ax2.plot(df_merged_all['State'], df_merged_all['Total (Billions)'], color='y', marker='o', linestyle='-', label='Funding')
ax2.set_ylabel('Total (Billions)', color='y')
ax2.tick_params(axis='y', labelcolor='y')

# Rotate the x-axis labels
plt.xticks(rotation=90)  # Adjust the rotation angle as needed

# Add a legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax1.legend(lines, labels, loc='upper left')

# Add a title
plt.title('Allocation of the Infrastructure Investment and Jobs Act funding by State and Territory -  Other Party ')

plt.tight_layout()
plt.show()

# %% [markdown]
# As per the above graphs I do see some bias as per the allocation favoring the political interest of Biden Administration. If you see the states that voted for democrat received more funding. Some state that are more Republican did not receive more funding. One state that voted Libertarian did not receive much funding. Others were just as equal as the Democrat states.
